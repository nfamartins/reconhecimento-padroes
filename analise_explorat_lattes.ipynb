# %% [markdown]
# <a href="https://colab.research.google.com/github/nfamartins/reconhecimento-padroes/blob/main/analise_explorat_lattes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparando o ambiente

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Definindo um diretório base

# %%
import os
base_dir = '/content/drive/MyDrive/Projetos/each/sin5007'
os.chdir(base_dir)

# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Importando dados

# %% [markdown]
# ## Dicionários das tabelas

# %%
dic = pd.read_csv('dados/dicionario_tabelas.csv', sep = '\t')

# %%
dic
# Out:
#     nome_tabela                            campos             col_names  \
# 0         areas                          LattesID             id_lattes
# 1         areas         SEQUENCIA-AREA-DE-ATUACAO      area_atuacao_seq
# 2         areas  NOME-GRANDE-AREA-DO-CONHECIMENTO           grande_area
# 3         areas      NOME-DA-AREA-DO-CONHECIMENTO     area_conhecimento
# 4         areas  NOME-DA-SUB-AREA-DO-CONHECIMENTO  subarea_conhecimento
# ..          ...                               ...                   ...
# 78  orientacoes  NOME-GRANDE-AREA-DO-CONHECIMENTO           grande_area
# 79  orientacoes      NOME-DA-AREA-DO-CONHECIMENTO     area_conhecimento
# 80  orientacoes  NOME-DA-SUB-AREA-DO-CONHECIMENTO  subarea_conhecimento
# 81  orientacoes      TIPO-DE-ORIENTACAO-CONCLUIDA         especialidade
# 82  orientacoes                TIPO-DE-ORIENTACAO       tipo_orientacao
#
#                                             descricao
# 0                                                 NaN
# 1   [int] contador do número de áreas de atuações ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 78                                     da orientação?
# 79                                     da orientação?
# 80                                     da orientação?
# 81                                     da orientação?
# 82                                                NaN
#
# [83 rows x 4 columns]

# %% [markdown]
# ## Dados gerais dos doutores no Lattes

# %%
# dados gerais dos doutores
# vou ler todos os campos como object, caso quisesse especificar, basta passar um dicionário
docs = pd.read_csv('dados/gerais.csv', sep='\t', header = None, dtype = 'object')

# %%
#verificando
docs.head()
# Out:
#                   0                          1         2       3         4  \
# 0  0000039015885890   Tárcio de Almeida Vieira  29042021  123614     Ipiau
# 1  0000104116232000                Andre Zuber  31082018  134523     Irati
# 2  0000111305956227      Tecia Vieira Carvalho  24092021  163956  Parnaiba
# 3  0000174385402367  Juliana Vieira de Freitas  04062021  111421  Sorocaba
# 4  0000183606503103     Luiza Cristina Lacerda  25112014  004523  Goliânia
#
#     5       6  7    8
# 0  BA  Brasil  B  NaN
# 1  PR  Brasil  B  NaN
# 2  PI  Brasil  B  NaN
# 3  SP  Brasil  B  NaN
# 4  GO  Brasil  B  NaN

# %%
# a tabela está vindo com uma coluna a mais (vazia) do que o esperado, então vamos dropa-la
docs.drop(8, axis=1, inplace=True)

# e renomear com os col_names do dicionario
docs.columns = dic[dic['nome_tabela'] == 'gerais']['col_names'].values

# %%
# verificando
docs.head()
# Out:
#           id_lattes              nome_completo data_update hora_update  \
# 0  0000039015885890   Tárcio de Almeida Vieira    29042021      123614
# 1  0000104116232000                Andre Zuber    31082018      134523
# 2  0000111305956227      Tecia Vieira Carvalho    24092021      163956
# 3  0000174385402367  Juliana Vieira de Freitas    04062021      111421
# 4  0000183606503103     Luiza Cristina Lacerda    25112014      004523
#
#   cidade_nascimento uf_nascimento pais_nascimento nacionalidade
# 0             Ipiau            BA          Brasil             B
# 1             Irati            PR          Brasil             B
# 2          Parnaiba            PI          Brasil             B
# 3          Sorocaba            SP          Brasil             B
# 4          Goliânia            GO          Brasil             B

# %%
print(len(docs))
print(docs['id_lattes'].nunique())
# Out:
# 373590
# 373590

# %% [markdown]
# Ok. Banco de dados dos locais de nascimento, únicos para cada id_lattes do banco

# %% [markdown]
# ## Áreas de atuação dos doutores

# %%
# dados gerais dos doutores
# vou ler todos os campos como object, caso quisesse especificar, basta passar um dicionário
area = pd.read_csv('dados/areas.csv', sep='\t', header = None, dtype='object')

# %%
#verificando
area.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# dtype: object

# %%
#verificando
area.head()
# Out:
#                   0  1                           2                   3  \
# 0  0000039015885890  3  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 1  0000039015885890  2  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 2  0000039015885890  1  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 3  0000104116232000  1                 ENGENHARIAS  Engenharia Química
# 4  0000111305956227  6  CIENCIAS_SOCIAIS_APLICADAS       Administração
#
#                                                    4    5
# 0  Dispositivos Ópticos, Optoeletrônicos e Fotônicos  NaN
# 1                          Ótica não linear Aplicada  NaN
# 2         Materiais Eletro-Ópticos e Fotorrefrativos  NaN
# 3                                                NaN  NaN
# 4               Administração de Setores Específicos  NaN

# %%
# renomear com os col_names do dicionario
area.columns = dic[dic['nome_tabela'] == 'areas']['col_names'].values

# %%
#verificando
area.head()
# Out:
#           id_lattes area_atuacao_seq                 grande_area  \
# 0  0000039015885890                3  CIENCIAS_EXATAS_E_DA_TERRA
# 1  0000039015885890                2  CIENCIAS_EXATAS_E_DA_TERRA
# 2  0000039015885890                1  CIENCIAS_EXATAS_E_DA_TERRA
# 3  0000104116232000                1                 ENGENHARIAS
# 4  0000111305956227                6  CIENCIAS_SOCIAIS_APLICADAS
#
#     area_conhecimento                               subarea_conhecimento  \
# 0              Física  Dispositivos Ópticos, Optoeletrônicos e Fotônicos
# 1              Física                          Ótica não linear Aplicada
# 2              Física         Materiais Eletro-Ópticos e Fotorrefrativos
# 3  Engenharia Química                                                NaN
# 4       Administração               Administração de Setores Específicos
#
#   especialidade
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
print(len(area))
print(area['id_lattes'].nunique())
# Out:
# 1256369
# 344540

# %% [markdown]
# Selecionando apenas a área de atuação principal (area_atuacao == 1)

# %%
area = area[area['area_atuacao_seq'] == '1']
print(len(area))
print(area['id_lattes'].nunique())
# Out:
# 343065
# 343019

# %% [markdown]
# Ainda existem dados repetivos na tabela, mas por enquanto, vamos ignorar o erro e eliminar os os ids repetidos

# %%
area = area.drop_duplicates(subset='id_lattes', keep='first')
print(len(area))
# Out:
# 343019

# %% [markdown]
# Adicionando esses dados ao df principal (doc)

# %%
docs = pd.merge(docs, area, on='id_lattes', how='left')

# %%
docs.head()
# Out:
#           id_lattes              nome_completo data_update hora_update  \
# 0  0000039015885890   Tárcio de Almeida Vieira    29042021      123614
# 1  0000104116232000                Andre Zuber    31082018      134523
# 2  0000111305956227      Tecia Vieira Carvalho    24092021      163956
# 3  0000174385402367  Juliana Vieira de Freitas    04062021      111421
# 4  0000183606503103     Luiza Cristina Lacerda    25112014      004523
#
#   cidade_nascimento uf_nascimento pais_nascimento nacionalidade  \
# 0             Ipiau            BA          Brasil             B
# 1             Irati            PR          Brasil             B
# 2          Parnaiba            PI          Brasil             B
# 3          Sorocaba            SP          Brasil             B
# 4          Goliânia            GO          Brasil             B
#
#   area_atuacao_seq                 grande_area   area_conhecimento  \
# 0                1  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 1                1                 ENGENHARIAS  Engenharia Química
# 2                1  CIENCIAS_EXATAS_E_DA_TERRA             Química
# 3                1                 ENGENHARIAS  Engenharia Química
# 4                1         CIENCIAS_BIOLOGICAS        Farmacologia
#
#                           subarea_conhecimento     especialidade
# 0   Materiais Eletro-Ópticos e Fotorrefrativos               NaN
# 1                                          NaN               NaN
# 2                             Química Orgânica  Síntese Orgânica
# 3  Processos Industriais de Engenharia Química               NaN
# 4                                          NaN               NaN

# %%
len(docs)
# Out:
# 373590

# %% [markdown]
# ## Importando dados de papers (periódicos)

# %%
# o arquivo está com problemas de padronização dos dados
# usaremos error_bad_lines=False para conseguir ler os dados, e trataremos esses problemas em outro momento
papers = pd.read_csv('dados/periodicos.csv', sep='\t', header = None, on_bad_lines='warn', dtype = 'object',
                     names=dic[dic['nome_tabela'] == 'periodicos']['col_names'].values)

# %%
papers.head()
# Out:
#           id_lattes ano_artigo  \
# 0  0041178224320635       2020
# 1  0041178224320635       2005
# 2  0041178224320635       2012
# 3  0041178224320635       2017
# 4  0041178224320635       2012
#
#                                        titulo_artigo  natureza     idioma  \
# 0  Facial profile changes due to bone cement graf...  COMPLETO     Inglês
# 1  Correlação entre Espessura Gengival nos Enxert...  COMPLETO  Português
# 2  . Enxerto de tecido conjuntivo subepitelial co...  COMPLETO  Português
# 3  Four-year follow-up of a polymethyl methacryla...  COMPLETO  Português
# 4  Aumento de coroa estético associado ao reposic...  COMPLETO  Português
#
#        issn                      tituto_periodico pagina_inicial pagina_final  \
# 0  21776709  DENTAL PRESS JOURNAL OF ORTHODONTICS             44           55
# 1  01047914            ROBRAC (GOIÂNIA. IMPRESSO)             27           31
# 2  24477567                        ISSN 2447-7567            165          170
# 3  00014265          ACADEMY OF GENERAL DENTISTRY             48           53
# 4  19813708             ROBRAC (ONLINE) (GOIÂNIA)            493          497
#
#   volume fasciculo serie local_publicacao pais_publicacao  \
# 0     25       NaN   NaN              NaN             NaN
# 1     14       NaN    38              NaN             NaN
# 2      6       NaN  2012              NaN             NaN
# 3     65       NaN   NaN              NaN             NaN
# 4     21       NaN   NaN              NaN             NaN
#
#                                   doi        grande_area area_conhecimento  \
# 0  10.1590/2177-6709.25.2.044-051.oar  CIENCIAS_DA_SAUDE               NaN
# 1                                 NaN                NaN               NaN
# 2                                 NaN                NaN               NaN
# 3                                 NaN                NaN               NaN
# 4                                 NaN  CIENCIAS_DA_SAUDE               NaN
#
#   subarea_conhecimento especialidade
# 0          Periodontia   Periodontia
# 1                  NaN           NaN
# 2                  NaN           NaN
# 3                  NaN           NaN
# 4          Periodontia   Periodontia

# %% [markdown]
# Fazendo uma análise simples de contagem de papers publicados (total geral). Depois precisaremos fazer análises mais sofisticadas, por ano, antes/após o doutorado, impacto das revistas, área de publicação, etc.

# %%
papers_qtd = papers.groupby('id_lattes').size().reset_index(name='n_papers')

# %%
papers_qtd.head()
# Out:
#           id_lattes  n_papers
# 0  0000039015885890         9
# 1  0000104116232000         8
# 2  0000111305956227        17
# 3  0000174385402367         5
# 4  0000183606503103         4

# %%
len(papers_qtd)
# Out:
# 338023

# %% [markdown]
# Adicionando ao df principal (docs)

# %%
docs = pd.merge(docs, papers_qtd, on='id_lattes', how='left')

# %%
docs.head()
# Out:
#           id_lattes              nome_completo data_update hora_update  \
# 0  0000039015885890   Tárcio de Almeida Vieira    29042021      123614
# 1  0000104116232000                Andre Zuber    31082018      134523
# 2  0000111305956227      Tecia Vieira Carvalho    24092021      163956
# 3  0000174385402367  Juliana Vieira de Freitas    04062021      111421
# 4  0000183606503103     Luiza Cristina Lacerda    25112014      004523
#
#   cidade_nascimento uf_nascimento pais_nascimento nacionalidade  \
# 0             Ipiau            BA          Brasil             B
# 1             Irati            PR          Brasil             B
# 2          Parnaiba            PI          Brasil             B
# 3          Sorocaba            SP          Brasil             B
# 4          Goliânia            GO          Brasil             B
#
#   area_atuacao_seq                 grande_area   area_conhecimento  \
# 0                1  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 1                1                 ENGENHARIAS  Engenharia Química
# 2                1  CIENCIAS_EXATAS_E_DA_TERRA             Química
# 3                1                 ENGENHARIAS  Engenharia Química
# 4                1         CIENCIAS_BIOLOGICAS        Farmacologia
#
#                           subarea_conhecimento     especialidade  n_papers
# 0   Materiais Eletro-Ópticos e Fotorrefrativos               NaN       9.0
# 1                                          NaN               NaN       8.0
# 2                             Química Orgânica  Síntese Orgânica      17.0
# 3  Processos Industriais de Engenharia Química               NaN       5.0
# 4                                          NaN               NaN       4.0

# %%
len(docs)
# Out:
# 373590

# %% [markdown]
# ## Importando dados de orientações

# %%
orientacoes = pd.read_csv('dados/orientacoes.csv', sep='\t', header = None, dtype = 'object',
                     names=dic[dic['nome_tabela'] == 'orientacoes']['col_names'].values)

# %%
orientacoes.head()
# Out:
#           id_lattes                                natureza_orientacao  \
# 0  0041178224320635                            Dissertação de mestrado
# 1  0041178224320635                            Dissertação de mestrado
# 2  0041178224320635                                  Tese de doutorado
# 3  0041178224320635  MONOGRAFIA_DE_CONCLUSAO_DE_CURSO_APERFEICOAMEN...
# 4  0041178224320635  MONOGRAFIA_DE_CONCLUSAO_DE_CURSO_APERFEICOAMEN...
#
#   status_orientacao ano_orientacao         nome_orientador id_instituicao  \
# 0         CONCLUIDA           1996           Sérgio Loiola   010600000009
# 1         CONCLUIDA           1996    Raulino Naves Borges   010600000009
# 2         CONCLUIDA           2013    Germana Jayme Borges   010600000009
# 3         CONCLUIDA           1996  Sirlene Rossi Mendonça   010600000009
# 4         CONCLUIDA           1996    Djalma Ribeiro Neves   010600000009
#
#                 nome_instituicao  id_curso bolsa_flag id_agencia_financiadora  \
# 0  Universidade Federal de Goiás  90000007        NAO                     NaN
# 1  Universidade Federal de Goiás  90000007        NAO                     NaN
# 2  Universidade Federal de Goiás  60026987        SIM            045000000000
# 3  Universidade Federal de Goiás  90000014        NAO                     NaN
# 4  Universidade Federal de Goiás  90000014        NAO                     NaN
#
#                            nome_agencia_financiadora  \
# 0                                                NaN
# 1                                                NaN
# 2  Coordenação de Aperfeiçoamento de Pessoal de N...
# 3                                                NaN
# 4                                                NaN
#
#                                    titulo_orientacao id_orientado  \
# 0     Pesquisa sobre adesão das resinas na porcelana          NaN
# 1       Relação entre desarmonia oclusal e cefaléias          NaN
# 2  Avaliação da tomografia computadorizada de fei...          NaN
# 3  Limites da indicação das próteses sob o ponto ...          NaN
# 4  Tempo de cicatrização para os preparos após in...          NaN
#
#                    nome_curso        grande_area area_conhecimento  \
# 0  Odontologia Prótese Dental  CIENCIAS_DA_SAUDE               NaN
# 1  Odontologia Prótese Dental  CIENCIAS_DA_SAUDE               NaN
# 2           Ciências da Saúde  CIENCIAS_DA_SAUDE               NaN
# 3            Prótese Dentária  CIENCIAS_DA_SAUDE               NaN
# 4            Prótese Dentária  CIENCIAS_DA_SAUDE               NaN
#
#    subarea_conhecimento         especialidade       tipo_orientacao
# 0  Clínica Odontológica                   NaN  ORIENTADOR_PRINCIPAL
# 1  Clínica Odontológica                   NaN  ORIENTADOR_PRINCIPAL
# 2           Periodontia                   NaN         CO_ORIENTADOR
# 3  Clínica Odontológica  ORIENTADOR_PRINCIPAL                   NaN
# 4  Clínica Odontológica  ORIENTADOR_PRINCIPAL                   NaN

# %%
orientacoes['natureza_orientacao'].unique()
# Out:
# array(['Dissertação de mestrado', 'Tese de doutorado',
#        'MONOGRAFIA_DE_CONCLUSAO_DE_CURSO_APERFEICOAMENTO_E_ESPECIALIZACAO',
#        'TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO', 'INICIACAO_CIENTIFICA',
#        'Monografia de conclusão de curso de aperfeiçoamento/especialização',
#        'Trabalho de conclusão de curso de graduação',
#        'Iniciação Científica', 'ORIENTACAO-DE-OUTRA-NATUREZA',
#        'Supervisão de pós-doutorado', 'Orientação de outra natureza',
#        'Disserta&amp;ccedil;&amp;atilde;o de mestrado',
#        'Monografia de conclus&amp;atilde;o de curso de aperfei&amp;ccedil;oamento/especializa&amp;ccedil;&amp;atilde;o',
#        'Trabalho de conclus&amp;atilde;o de curso de gradua&amp;ccedil;&amp;atilde;o',
#        'Inicia&amp;ccedil;&amp;atilde;o Cient&amp;iacute;fica',
#        'Disserta??o de mestrado', 'Inicia??o Cient?fica'], dtype=object)

# %% [markdown]
# Contando a quantidade de orientações. Neste momento, devido à não padronização do campo natureza_orientacao, vamos usar apenas uma contagem total de orientações.

# %%
orientacoes_qtd = orientacoes.groupby('id_lattes').size().reset_index(name='n_orientacoes')

# %%
orientacoes_qtd.head()
# Out:
#           id_lattes  n_orientacoes
# 0  0000104116232000              9
# 1  0000111305956227             41
# 2  0000183606503103              9
# 3  0000221437884487             27
# 4  0000230621439945             29

# %%
len(orientacoes_qtd)
# Out:
# 268561

# %% [markdown]
# Adicionando ao df proncipal (docs)

# %%
docs = pd.merge(docs, orientacoes_qtd, on='id_lattes', how='left')
docs.head()
# Out:
#           id_lattes              nome_completo data_update hora_update  \
# 0  0000039015885890   Tárcio de Almeida Vieira    29042021      123614
# 1  0000104116232000                Andre Zuber    31082018      134523
# 2  0000111305956227      Tecia Vieira Carvalho    24092021      163956
# 3  0000174385402367  Juliana Vieira de Freitas    04062021      111421
# 4  0000183606503103     Luiza Cristina Lacerda    25112014      004523
#
#   cidade_nascimento uf_nascimento pais_nascimento nacionalidade  \
# 0             Ipiau            BA          Brasil             B
# 1             Irati            PR          Brasil             B
# 2          Parnaiba            PI          Brasil             B
# 3          Sorocaba            SP          Brasil             B
# 4          Goliânia            GO          Brasil             B
#
#   area_atuacao_seq                 grande_area   area_conhecimento  \
# 0                1  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 1                1                 ENGENHARIAS  Engenharia Química
# 2                1  CIENCIAS_EXATAS_E_DA_TERRA             Química
# 3                1                 ENGENHARIAS  Engenharia Química
# 4                1         CIENCIAS_BIOLOGICAS        Farmacologia
#
#                           subarea_conhecimento     especialidade  n_papers  \
# 0   Materiais Eletro-Ópticos e Fotorrefrativos               NaN       9.0
# 1                                          NaN               NaN       8.0
# 2                             Química Orgânica  Síntese Orgânica      17.0
# 3  Processos Industriais de Engenharia Química               NaN       5.0
# 4                                          NaN               NaN       4.0
#
#    n_orientacoes
# 0            NaN
# 1            9.0
# 2           41.0
# 3            NaN
# 4            9.0

# %% [markdown]
# ## Importando dados de formação

# %%
formacao = pd.read_csv('dados/formacoes.csv', sep='\t', header = None, dtype = 'object',
                     names=dic[dic['nome_tabela'] == 'formacoes']['col_names'].values)

# %%
formacao.head()
# Out:
#           id_lattes formacao_seq nivel_formacao nivel ano_inicio ano_fim  \
# 0  0000039015885890           10  POS-DOUTORADO     5       2017     NaN
# 1  0000039015885890            8  POS-DOUTORADO     5       2015    2017
# 2  0000039015885890            7  POS-DOUTORADO     5       2014    2015
# 3  0000039015885890            9  POS-DOUTORADO     5       2016    2017
# 4  0000039015885890            3      DOUTORADO     4       2010    2014
#
#    status_curso nome_curso                                   nome_instituicao  \
# 0  EM_ANDAMENTO        NaN  Instituto de Astronomia, Geofísica e Ciências ...
# 1     CONCLUIDO        NaN     Instituto de Pesquisas Energeticas e Nucleares
# 2     CONCLUIDO        NaN              Instituto de Física, USP - São Carlos
# 3     CONCLUIDO        NaN                        Universidade Federal do ABC
# 4     CONCLUIDO     Física                        Universidade Federal do ABC
#
#   bolsa_flag
# 0        SIM
# 1        SIM
# 2        SIM
# 3        SIM
# 4        SIM

# %% [markdown]
# Determinando quantidade de pós doc

# %%
formacao['nivel_formacao'].unique()
# Out:
# array(['POS-DOUTORADO', 'DOUTORADO', 'MESTRADO', 'GRADUACAO',
#        'ESPECIALIZACAO', 'APERFEICOAMENTO',
#        'CURSO-TECNICO-PROFISSIONALIZANTE', 'ENSINO-MEDIO-SEGUNDO-GRAU',
#        'ENSINO-FUNDAMENTAL-PRIMEIRO-GRAU', 'MESTRADO-PROFISSIONALIZANTE',
#        'RESIDENCIA-MEDICA', 'LIVRE-DOCENCIA'], dtype=object)

# %% [markdown]
# Filtrando para apenas pós-docs

# %%
formacao = formacao[formacao['nivel_formacao'] == 'POS-DOUTORADO']
print(len(formacao))
print(formacao['id_lattes'].nunique())
# Out:
# 155461
# 109371

# %%
formacao_qtd = formacao.groupby('id_lattes').size().reset_index(name='n_posdoc')

# %%
formacao_qtd.head()
# Out:
#           id_lattes  n_posdoc
# 0  0000039015885890         4
# 1  0000104116232000         1
# 2  0000111305956227         1
# 3  0000254371229748         1
# 4  0000325690951570         1

# %% [markdown]
# Adicionando ao df principal (docs)

# %%
docs = pd.merge(docs, formacao_qtd, on='id_lattes', how='left')

# %%
docs.head()
# Out:
#           id_lattes              nome_completo data_update hora_update  \
# 0  0000039015885890   Tárcio de Almeida Vieira    29042021      123614
# 1  0000104116232000                Andre Zuber    31082018      134523
# 2  0000111305956227      Tecia Vieira Carvalho    24092021      163956
# 3  0000174385402367  Juliana Vieira de Freitas    04062021      111421
# 4  0000183606503103     Luiza Cristina Lacerda    25112014      004523
#
#   cidade_nascimento uf_nascimento pais_nascimento nacionalidade  \
# 0             Ipiau            BA          Brasil             B
# 1             Irati            PR          Brasil             B
# 2          Parnaiba            PI          Brasil             B
# 3          Sorocaba            SP          Brasil             B
# 4          Goliânia            GO          Brasil             B
#
#   area_atuacao_seq                 grande_area   area_conhecimento  \
# 0                1  CIENCIAS_EXATAS_E_DA_TERRA              Física
# 1                1                 ENGENHARIAS  Engenharia Química
# 2                1  CIENCIAS_EXATAS_E_DA_TERRA             Química
# 3                1                 ENGENHARIAS  Engenharia Química
# 4                1         CIENCIAS_BIOLOGICAS        Farmacologia
#
#                           subarea_conhecimento     especialidade  n_papers  \
# 0   Materiais Eletro-Ópticos e Fotorrefrativos               NaN       9.0
# 1                                          NaN               NaN       8.0
# 2                             Química Orgânica  Síntese Orgânica      17.0
# 3  Processos Industriais de Engenharia Química               NaN       5.0
# 4                                          NaN               NaN       4.0
#
#    n_orientacoes  n_posdoc
# 0            NaN       4.0
# 1            9.0       1.0
# 2           41.0       1.0
# 3            NaN       NaN
# 4            9.0       NaN

# %% [markdown]
# ## Importando dados de atuação profissional

# %%
atuacao = pd.read_csv('dados/atuacoes.csv', sep='\t', header = None, dtype = 'object',
                     names=dic[dic['nome_tabela'] == 'atuacoes']['col_names'].values)

# %%
atuacao
# Out:
#                 id_lattes id_instituicao  \
# 0        0041178224320635   010600000009
# 1        0041178224320635   010600000009
# 2        0041178224320635   010600000009
# 3        0041178224320635   010600000009
# 4        0041178224320635   010600000009
# ...                   ...            ...
# 4854278  9973483576954517   001100000990
# 4854279  9973483576954517   446900000000
# 4854280  9973483576954517   001500000997
# 4854281  9973483576954517   001700000990
# 4854282  9973483576954517   002400000993
#
#                                           nome_instituicao ano_inicio ano_fim  \
# 0                            Universidade Federal de Goiás       2000     NaN
# 1                            Universidade Federal de Goiás       2000    2000
# 2                            Universidade Federal de Goiás       1997    1999
# 3                            Universidade Federal de Goiás       1994    1996
# 4                            Universidade Federal de Goiás       2018     NaN
# ...                                                    ...        ...     ...
# 4854278                                J.P.R. Medicamentos       2001    2002
# 4854279             Universidade Federal de Campina Grande       2010     NaN
# 4854280  Revista de Ciências Farmacêuticas Básica e Apl...       2011    2012
# 4854281        Revista Eletrônica Educação Ciência e Saúde       2014    2016
# 4854282         Fórum Nacional de Farmácias Universitárias       2015    2017
#
#              tipo_vinculo enquadramento_fucional enquadramento_fucional_outro  \
# 0        SERVIDOR_PUBLICO                  LIVRE        Professor Adjunto III
# 1        SERVIDOR_PUBLICO                  LIVRE         Professor Adjunto II
# 2        SERVIDOR_PUBLICO                  LIVRE           Profesor Adjunto I
# 3        SERVIDOR_PUBLICO                  LIVRE           Professor Auxiliar
# 4        SERVIDOR_PUBLICO      PROFESSOR_TITULAR                          NaN
# ...                   ...                    ...                          ...
# 4854278             LIVRE                  LIVRE                 Farmacêutica
# 4854279  SERVIDOR_PUBLICO      PROFESSOR_TITULAR                          NaN
# 4854280             LIVRE                  LIVRE                          NaN
# 4854281             LIVRE                  LIVRE                          NaN
# 4854282             LIVRE                  LIVRE                 Coordenadora
#
#         carga_horaria_sem dedicacao_exclusiva_flag
# 0                       0                      SIM
# 1                       0                      SIM
# 2                       0                      SIM
# 3                      20                      NAO
# 4                     NaN                      SIM
# ...                   ...                      ...
# 4854278                20                      NAO
# 4854279                40                      SIM
# 4854280               NaN                      NAO
# 4854281               NaN                      NAO
# 4854282                 2                      NAO
#
# [4854283 rows x 10 columns]

# %%
atuacao['tipo_vinculo'].unique()
# Out:
# array(['SERVIDOR_PUBLICO', 'OUTRO', 'LIVRE', 'CELETISTA',
#        'PROFESSOR_VISITANTE', 'COLABORADOR', nan, 'BOLSISTA_RECEM_DOUTOR'],
#       dtype=object)

# %%
atuacao['enquadramento_fucional'].unique()
# Out:
# array(['LIVRE', 'PROFESSOR_TITULAR', 'OUTRO', nan], dtype=object)

# %% [markdown]
# # Fazendo uma análise exploratória

# %%
# !pip install pandas_profiling

# %%
import pandas_profiling
# Out:
# <ipython-input-51-6a00893fb3e1>:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
# !pip install ydata-profiling

# %%
docs.dtypes

# %%
import ydata_profiling

# %%
profile = ydata_profiling.ProfileReport(docs)

# Salva o relatório em um arquivo HTML
profile.to_file("out/relatorio_analise.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# apenas para teste
